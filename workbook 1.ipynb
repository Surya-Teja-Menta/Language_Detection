# %%
import pandas as pd

# %%
df=pd.read_csv('Language Detection.csv')

# %%
df
# Out:
#                                                     Text Language
# 0       Nature, in the broadest sense, is the natural...  English
# 1      "Nature" can refer to the phenomena of the phy...  English
# 2      The study of nature is a large, if not the onl...  English
# 3      Although humans are part of nature, human acti...  English
# 4      [1] The word nature is borrowed from the Old F...  English
# ...                                                  ...      ...
# 10332  ನಿಮ್ಮ ತಪ್ಪು ಏನು ಬಂದಿದೆಯೆಂದರೆ ಆ ದಿನದಿಂದ ನಿಮಗೆ ಒ...  Kannada
# 10333  ನಾರ್ಸಿಸಾ ತಾನು ಮೊದಲಿಗೆ ಹೆಣಗಾಡುತ್ತಿದ್ದ ಮಾರ್ಗಗಳನ್...  Kannada
# 10334  ಹೇಗೆ ' ನಾರ್ಸಿಸಿಸಮ್ ಈಗ ಮರಿಯನ್ ಅವರಿಗೆ ಸಂಭವಿಸಿದ ಎ...  Kannada
# 10335  ಅವಳು ಈಗ ಹೆಚ್ಚು ಚಿನ್ನದ ಬ್ರೆಡ್ ಬಯಸುವುದಿಲ್ಲ ಎಂದು ...  Kannada
# 10336  ಟೆರ್ರಿ ನೀವು ನಿಜವಾಗಿಯೂ ಆ ದೇವದೂತನಂತೆ ಸ್ವಲ್ಪ ಕಾಣು...  Kannada
#
# [10337 rows x 2 columns]

# %%
df.Language.value_counts()
# Out:
# English       1385
# French        1014
# Spanish        819
# Portugeese     739
# Italian        698
# Russian        692
# Sweedish       676
# Malayalam      594
# Dutch          546
# Arabic         536
# Turkish        474
# German         470
# Tamil          469
# Danish         428
# Kannada        369
# Greek          365
# Hindi           63
# Name: Language, dtype: int64

# %%
malay=df[df.Language=='Malayalam']

# %%
malay
# Out:
#                                                    Text   Language
# 1385  ഭൗതികപ്രപഞ്ചത്തെ മൊത്തത്തിൽ സൂചിപ്പിക്കുന്ന പദ...  Malayalam
# 1386  ഭൗതികപ്രതിഭാസങ്ങളും ജീവനും പ്രകൃതിയുടെ ഘടകങ്ങള...  Malayalam
# 1387  മനുഷ്യനിർമിതമായ വസ്തുക്കളെ പ്രകൃതിയുടെ ഭാഗമായി...  Malayalam
# 1388  അവയെ കൃത്രിമം എന്ന് വിശേഷിപ്പിക്കുന്നുഅഭിപ്രായ...  Malayalam
# 1389  പ്രകൃതി എന്ന പദം പ്രപഞ്ചത്തെയും അതിലെ സമസ്ത പ്...  Malayalam
# ...                                                 ...        ...
# 1974  നിങ്ങളുടെ തെറ്റ് വന്നത് ആ ദിവസം മുതൽ നിങ്ങൾക്ക...  Malayalam
# 1975  നാർസിസ ആദ്യം പാടുപെട്ട വഴികൾ മാറ്റി, പക്ഷേ പതു...  Malayalam
# 1976  എങ്ങനെ' സംഭവിച്ച എല്ലാ കാര്യങ്ങളും ഇപ്പോൾ മരിയ...  Malayalam
# 1977  അവൾക്കറിയാമോ, അവൾക്ക് ഇപ്പോൾ കൂടുതൽ സ്വർണ്ണ റൊ...  Malayalam
# 1978  ടെറി നിങ്ങൾ യഥാർത്ഥത്തിൽ ആ മാലാഖയെപ്പോലെയാണ് ക...  Malayalam
#
# [594 rows x 2 columns]

# %%
import translators as ts
ts.google
ts._google.language_map

# %%
phrase = mal[78]
l=ts.google(phrase, from_language='ml', to_language='hi')

# %%
mal=malay.Text.tolist()

# %%
ben=[]
for i in range(len(mal)):
    ben.append(ts.google(mal[i],from_language='ml',to_language='bn'))

# %%
l
# Out:
# 'विकिपीडिया एक संतुलित दृष्टि संतुलित दृष्टि है जो इस तरह से लिंग और जुड़ने की है।'

# %%
ben
# Out:
# ['প্রাকৃতিক (জার্মান: নাটুর, ফরাসী, ফরাসী, ফরাসী, ইংরেজি: ন্যাচারালিজা, পর্তুগিজ: প্রকৃতি।',
#  'শারীরিক ঘটনা এবং জীবন প্রকৃতির কারণ।',
#  'মনুষ্যনির্মিত বস্তুগুলি প্রকৃতির অংশ হিসাবে বিবেচিত হয় না।',
#  'ইংরেজির স্বাধীনতার কৃত্রিমতা হওয়ার স্বাধীনতার স্বাধীনতা ইউনাইটেড পল নাটুরা থেকে।',
#  'প্রকৃতির শব্দটিতে মহাবিশ্ব এবং সমস্ত জটিল ঘটনা রয়েছে।',
#  'পৃথিবী একটি অন্যায় জায়গা যা সুপরিচিত গ্রহে বাস করে।',
#  'সৌরজগতে সূর্য থেকে পৃথিবী তৃতীয় স্থান।',
#  'বলে, মহাবিশ্বের পরিবেশের বাইরে স্থান (?)',
#  'যাচাইকরণ এবং রেফারেন্স == নোট এবং রেফারেন্স == প্রাকৃতিক হোমপেজে।',
#  'বায়ুমণ্ডলীয় বিজ্ঞান · \n ইভেন্ট সায়েন্স · \n জিওসায়েন্সেস · \n মৃত্তিকা বিজ্ঞান · \n হাইডারোলজি পুনর্মিলন বিষয়: জীববিজ্ঞান · \n রসায়ন · \n পরিবেশ বান্ধব নকশা · \n পরিবেশগত অর্থনীতি · \n পরিবেশগত নীতিশাস্ত্র · \n পরিবেশ আইন · \n পদার্থবিজ্ঞান · \n দূষণ নিয়ন্ত্রণ · \n টেকসইতা · \n উইকিপিডিয়া পরিবেশগত প্রযুক্তির অপচয় তৈরির জন্য একটি স্বাধীন এবং বিস্তৃত এনসাইক্লোপিডিয়া তৈরি করার জন্য একটি সম্মিলিত প্রকল্প।',
# ...

# %%
bendf=pd.DataFrame(ben)

# %%
bendf
# Out:
#                                                      0
# 0    প্রাকৃতিক (জার্মান: নাটুর, ফরাসী, ফরাসী, ফরাসী...
# 1                 শারীরিক ঘটনা এবং জীবন প্রকৃতির কারণ।
# 2    মনুষ্যনির্মিত বস্তুগুলি প্রকৃতির অংশ হিসাবে বি...
# 3    ইংরেজির স্বাধীনতার কৃত্রিমতা হওয়ার স্বাধীনতার...
# 4    প্রকৃতির শব্দটিতে মহাবিশ্ব এবং সমস্ত জটিল ঘটনা...
# ..                                                 ...
# 589        আপনি সেদিন থেকে আপনাকে ভাল কিছু দিতে পারেন।
# 590  নরসিসা প্রথমে পরিবর্তিত হয়েছিল, তবে আস্তে আস্...
# 591  "এখন যা ঘটেছিল তা মারিয়ান তাদের বলেছিল, সেই স...
# 592               তিনি জানেন, তার বেশি সোনার রুটি নেই।
# 593  টেরি আপনি আসলে সেই দেবদূতের মতো দেখতে, তবে আমি...
#
# [594 rows x 1 columns]

# %%
stli=['Bengali' for i in range(len(ben))]

# %%
len(ben),len(stli)
# Out:
# (594, 594)

# %%
bendf=pd.DataFrame(ben,stli)

# %%
bendf=bendf.rename(columns={0:'Text','':'Language'})

# %%
bendf.columns
# Out:
# Index(['Text'], dtype='object')

# %%
bendf.to_csv('bendi.csv')

# %%
dft=pd.read_csv('bendi.csv')

# %%
dft.rename(columns={'Unnamed: 0':'Language'},inplace=True)

# %%
dft=dft[['Text','Language']]

# %%
dft.to_csv('bendi.csv')

# %%
dft
# Out:
#                                                   Text Language
# 0    প্রাকৃতিক (জার্মান: নাটুর, ফরাসী, ফরাসী, ফরাসী...  Bengali
# 1                 শারীরিক ঘটনা এবং জীবন প্রকৃতির কারণ।  Bengali
# 2    মনুষ্যনির্মিত বস্তুগুলি প্রকৃতির অংশ হিসাবে বি...  Bengali
# 3    ইংরেজির স্বাধীনতার কৃত্রিমতা হওয়ার স্বাধীনতার...  Bengali
# 4    প্রকৃতির শব্দটিতে মহাবিশ্ব এবং সমস্ত জটিল ঘটনা...  Bengali
# ..                                                 ...      ...
# 589        আপনি সেদিন থেকে আপনাকে ভাল কিছু দিতে পারেন।  Bengali
# 590  নরসিসা প্রথমে পরিবর্তিত হয়েছিল, তবে আস্তে আস্...  Bengali
# 591  "এখন যা ঘটেছিল তা মারিয়ান তাদের বলেছিল, সেই স...  Bengali
# 592               তিনি জানেন, তার বেশি সোনার রুটি নেই।  Bengali
# 593  টেরি আপনি আসলে সেই দেবদূতের মতো দেখতে, তবে আমি...  Bengali
#
# [594 rows x 2 columns]

# %%
df
# Out:
#                                                     Text Language
# 0       Nature, in the broadest sense, is the natural...  English
# 1      "Nature" can refer to the phenomena of the phy...  English
# 2      The study of nature is a large, if not the onl...  English
# 3      Although humans are part of nature, human acti...  English
# 4      [1] The word nature is borrowed from the Old F...  English
# ...                                                  ...      ...
# 10332  ನಿಮ್ಮ ತಪ್ಪು ಏನು ಬಂದಿದೆಯೆಂದರೆ ಆ ದಿನದಿಂದ ನಿಮಗೆ ಒ...  Kannada
# 10333  ನಾರ್ಸಿಸಾ ತಾನು ಮೊದಲಿಗೆ ಹೆಣಗಾಡುತ್ತಿದ್ದ ಮಾರ್ಗಗಳನ್...  Kannada
# 10334  ಹೇಗೆ ' ನಾರ್ಸಿಸಿಸಮ್ ಈಗ ಮರಿಯನ್ ಅವರಿಗೆ ಸಂಭವಿಸಿದ ಎ...  Kannada
# 10335  ಅವಳು ಈಗ ಹೆಚ್ಚು ಚಿನ್ನದ ಬ್ರೆಡ್ ಬಯಸುವುದಿಲ್ಲ ಎಂದು ...  Kannada
# 10336  ಟೆರ್ರಿ ನೀವು ನಿಜವಾಗಿಯೂ ಆ ದೇವದೂತನಂತೆ ಸ್ವಲ್ಪ ಕಾಣು...  Kannada
#
# [10337 rows x 2 columns]

# %%
teldf=pd.read_csv('telugu.csv')

# %%
hindf=pd.read_csv('hindi.csv')

# %%
bendf=pd.read_csv('bendi.csv')

# %%
teldf=teldf.drop(['Unnamed: 0'],axis=1)

# %%
bendf=bendf.drop(['Unnamed: 0'],axis=1)

# %%
hindf=hindf.drop(['Unnamed: 0'],axis=1)

# %%
addi=pd.concat([teldf,hindf,bendf],axis=0)

# %%
addi.reset_index(inplace=True)

# %%
addi=addi.drop(['index'],axis=1)

# %%
addi
# Out:
#                                                    Text Language
# 0     నేచురల్ (జర్మన్: నేచుర్, ఫ్రెంచ్, ఫ్రెంచ్, ఫ్ర...   Telugu
# 1     భౌతిక దృగ్విషయం మరియు జీవితం ప్రకృతి యొక్క అంశ...   Telugu
# 2     మానవ నిర్మిత వస్తువులు ప్రకృతిలో భాగంగా పరిగణి...   Telugu
# 3     ఇంగ్లీష్ స్వేచ్ఛ యొక్క కృత్రిమతగా ఉండటానికి స్...   Telugu
# 4     ప్రకృతి స్వభావం అనే పదం విశ్వం మరియు సంక్లిష్ట...   Telugu
# ...                                                 ...      ...
# 1777        আপনি সেদিন থেকে আপনাকে ভাল কিছু দিতে পারেন।  Bengali
# 1778  নরসিসা প্রথমে পরিবর্তিত হয়েছিল, তবে আস্তে আস্...  Bengali
# 1779  "এখন যা ঘটেছিল তা মারিয়ান তাদের বলেছিল, সেই স...  Bengali
# 1780               তিনি জানেন, তার বেশি সোনার রুটি নেই।  Bengali
# 1781  টেরি আপনি আসলে সেই দেবদূতের মতো দেখতে, তবে আমি...  Bengali
#
# [1782 rows x 2 columns]

# %%
dfi=pd.concat([df,addi],axis=0)

# %%
dfi.to_csv('final.csv')
